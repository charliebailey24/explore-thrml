# %% [markdown]
# # THRML Exploration Notebook
#
# This notebook provides an interactive environment to explore the THRML library from Extropics.
#
# 📚 **Documentation**: https://docs.thrml.ai/en/latest/

# %%
# Import THRML
import thrml

print("THRML imported successfully!")
print(f"THRML module: {thrml}")

# %% [markdown]
# ## Explore THRML Functions
#
# Use this section to explore available functions and capabilities in THRML.

# %%
# List available attributes and methods
print("Available THRML attributes:")
print([attr for attr in dir(thrml) if not attr.startswith('_')])

# %% [markdown]
# ## Your Experiments
#
# Use the cells below to experiment with THRML features.

# %%
# Your code here
